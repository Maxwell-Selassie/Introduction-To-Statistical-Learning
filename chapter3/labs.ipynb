# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.outliers_influence import variance_inflation_factor as VIF

# %%
# Dataset : Boston.csv
# Goal : Build a linear regression model to predict median house value
df = pd.read_csv('Boston.csv')
print(f'Boston.csv loaded succesfully with {df.shape[0]} rows and {df.shape[1]} columns')
# Out:
# Boston.csv loaded succesfully with 506 rows and 14 columns
